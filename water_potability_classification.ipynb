# %% [markdown]
# <a href="https://colab.research.google.com/github/Gtpimenta/water_potability_classification/blob/main/water_potability_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1: Description

# %% [markdown]
# Access to safe drinking-water is essential to health, a basic human right and a component of effective policy for health protection. This is important as a health and development issue at a national, regional and local level. In some regions, it has been shown that investments in water supply and sanitation can yield a net economic benefit, since the reductions in adverse health effects and health care costs outweigh the costs of undertaking the interventions.

# %% [markdown]
# 1. pH value:
#
# PH is an important parameter in evaluating the acid–base balance of water. It is also the indicator of acidic or alkaline condition of water status. WHO has recommended maximum permissible limit of pH from 6.5 to 8.5. The current investigation ranges were 6.52–6.83 which are in the range of WHO standards.
# 2. Hardness:
#
# Hardness is mainly caused by calcium and magnesium salts. These salts are dissolved from geologic deposits through which water travels. The length of time water is in contact with hardness producing material helps determine how much hardness there is in raw water. Hardness was originally defined as the capacity of water to precipitate soap caused by Calcium and Magnesium.
# 3. Solids (Total dissolved solids - TDS):
#
# Water has the ability to dissolve a wide range of inorganic and some organic minerals or salts such as potassium, calcium, sodium, bicarbonates, chlorides, magnesium, sulfates etc. These minerals produced un-wanted taste and diluted color in appearance of water. This is the important parameter for the use of water. The water with high TDS value indicates that water is highly mineralized. Desirable limit for TDS is 500 mg/l and maximum limit is 1000 mg/l which prescribed for drinking purpose.
# 4. Chloramines:
#
# Chlorine and chloramine are the major disinfectants used in public water systems. Chloramines are most commonly formed when ammonia is added to chlorine to treat drinking water. Chlorine levels up to 4 milligrams per liter (mg/L or 4 parts per million (ppm)) are considered safe in drinking water.
# 5. Sulfate:
#
# Sulfates are naturally occurring substances that are found in minerals, soil, and rocks. They are present in ambient air, groundwater, plants, and food. The principal commercial use of sulfate is in the chemical industry. Sulfate concentration in seawater is about 2,700 milligrams per liter (mg/L). It ranges from 3 to 30 mg/L in most freshwater supplies, although much higher concentrations (1000 mg/L) are found in some geographic locations.
# 6. Conductivity:
#
# Pure water is not a good conductor of electric current rather’s a good insulator. Increase in ions concentration enhances the electrical conductivity of water. Generally, the amount of dissolved solids in water determines the electrical conductivity. Electrical conductivity (EC) actually measures the ionic process of a solution that enables it to transmit current. According to WHO standards, EC value should not exceeded 400 μS/cm.
# 7. Organic_carbon:
#
# Total Organic Carbon (TOC) in source waters comes from decaying natural organic matter (NOM) as well as synthetic sources. TOC is a measure of the total amount of carbon in organic compounds in pure water. According to US EPA < 2 mg/L as TOC in treated / drinking water, and < 4 mg/Lit in source water which is use for treatment.
# 8. Trihalomethanes:
#
# THMs are chemicals which may be found in water treated with chlorine. The concentration of THMs in drinking water varies according to the level of organic material in the water, the amount of chlorine required to treat the water, and the temperature of the water that is being treated. THM levels up to 80 ppm is considered safe in drinking water.
# 9. Turbidity:
#
# The turbidity of water depends on the quantity of solid matter present in the suspended state. It is a measure of light emitting properties of water and the test is used to indicate the quality of waste discharge with respect to colloidal matter. The mean turbidity value obtained for Wondo Genet Campus (0.98 NTU) is lower than the WHO recommended value of 5.00 NTU.
# 10. Potability:
#
# Indicates if water is safe for human consumption where 1 means Potable and 0 means Not potable.

# %% [markdown]
# source: https://www.kaggle.com/adityakadiwal/water-potability

# %% [markdown]
# # Part 2: Initial Analysis

# %% [markdown]
# Importing libraries:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Loading the dataset "water_potability.csv":

# %%
water = pd.read_csv('water_potability.csv')

# %% [markdown]
# First five rows of this dataset:

# %%
water.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
print(f'This dataset contains: {water.shape[0]} rows and {water.shape[1]} columns.')
# Out:
# This dataset contains: 3276 rows and 10 columns.

# %% [markdown]
# Some descriptive statistics of these variables:

# %%
water.describe().T
# Out:
#                   count          mean          std         min           25%  \
# ph               2785.0      7.080795     1.594320    0.000000      6.093092
# Hardness         3276.0    196.369496    32.879761   47.432000    176.850538
# Solids           3276.0  22014.092526  8768.570828  320.942611  15666.690297
# Chloramines      3276.0      7.122277     1.583085    0.352000      6.127421
# Sulfate          2495.0    333.775777    41.416840  129.000000    307.699498
# Conductivity     3276.0    426.205111    80.824064  181.483754    365.734414
# Organic_carbon   3276.0     14.284970     3.308162    2.200000     12.065801
# Trihalomethanes  3114.0     66.396293    16.175008    0.738000     55.844536
# Turbidity        3276.0      3.966786     0.780382    1.450000      3.439711
# Potability       3276.0      0.390110     0.487849    0.000000      0.000000
#
#                           50%           75%           max
# ph                   7.036752      8.062066     14.000000
# ...

# %% [markdown]
# Missing values by column:

# %%
water.isna().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# Percentage of potable and not potable samples:

# %%
perc_pot = water.Potability.value_counts().to_frame()
perc_pot.rename(index = {0:'Not potable', 1:'Potable'}, columns = {'Potability':'Total'}, inplace = True)
perc_pot['percentage'] = (perc_pot.Total/perc_pot.Total.sum())*100
perc_pot
# Out:
#              Total  percentage
# Not potable   1998   60.989011
# Potable       1278   39.010989

# %% [markdown]
# # Part 3: Cleaning Data

# %% [markdown]
# ## 3.1: Dealing with missing values

# %% [markdown]
# Percent of missing values by column:

# %%
missing = pd.DataFrame((water.isna().sum()/water.shape[0])*100, columns = ['Percent'])
missing
# Out:
#                    Percent
# ph               14.987790
# Hardness          0.000000
# Solids            0.000000
# Chloramines       0.000000
# Sulfate          23.840049
# Conductivity      0.000000
# Organic_carbon    0.000000
# Trihalomethanes   4.945055
# Turbidity         0.000000
# Potability        0.000000

# %%
sns.set_style('darkgrid')

# %%
ax = sns.barplot(x = missing.index, y = missing.Percent)
ax.figure.set_size_inches(16, 6)
ax.set_title('Percent of missing values', fontsize = 18, loc = 'left')
ax.set_ylabel('Percentage of missing values', fontsize = 14)
ax.set_xlabel('Features', fontsize = 14)
plt.xticks(rotation = 90)
ax = ax

# %%
water_v2 = water

# %%
water_v2.shape
# Out:
# (3276, 10)

# %% [markdown]
# > Importing Simple Imputer to fill these missing values

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')

# %% [markdown]
# ### 3.1.1: pH

# %%
water_v2.ph = imputer.fit_transform(water_v2[['ph']])

# %% [markdown]
# ### 3.1.2: Sulfate

# %%
water_v2.Sulfate = imputer.fit_transform(water_v2[['Sulfate']])

# %% [markdown]
# ### 3.1.3: Trihalomethanes

# %%
water_v2.Trihalomethanes = imputer.fit_transform(water_v2[['Trihalomethanes']])

# %% [markdown]
# # Part 4: EDA

# %%
water_v2.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.080795  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  333.775777    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  333.775777    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# > **Potability**

# %%
ax = sns.countplot(data = water_v2, x = 'Potability')
ax.figure.set_size_inches(12, 6)
ax.set_title('Potability', fontsize = 18, loc = 'left')
ax.set_xlabel('Potability', fontsize = 14)
ax.set_ylabel('Count', fontsize = 14)
plt.xticks([0, 1], ['Not Potable', 'Potable'])
ax = ax

# %% [markdown]
# > **Correlation Matrix**

# %%
ax = sns.heatmap(water_v2.corr(), annot = True, fmt = '.2f', square = True)
ax.figure.set_size_inches(16, 8)
ax.set_title('Correlation Matrix', fontsize = 18, loc = 'left')
ax = ax

# %% [markdown]
# As we can see from this matrix, all the features are poorly correlated. We can't compare this values with the target variable, since it's categoric, but if those variables are not correlated, it means that there is no linear relationship between these features.

# %% [markdown]
# > **Pairplot**

# %%
ax = sns.pairplot(water2, hue = 'Potability', kind = 'reg')

# %% [markdown]
# Through this pairplot, we can see that there is no linear relationship between the features, as we saw before.

# %% [markdown]
# # Part 5: Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
x = water_v2.iloc[:,:9]

# %%
y = water_v2.iloc[:,-1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, stratify = y, random_state = 1979)

# %% [markdown]
# ## 5.1: Baseline Classifier - 60,93%

# %%
from sklearn.dummy import DummyClassifier

# %%
dummy = DummyClassifier()

# %%
dummy.fit(x_train, y_train)
# Out:
# DummyClassifier()

# %%
y_pred = dummy.predict(x_test)

# %%
accuracy_dummy = accuracy_score(y_test, y_pred)
print(f'Accuracy score: {round(accuracy_dummy*100, 2)}')
# Out:
# Accuracy score: 60.93

# %%
confusion_dummy = confusion_matrix(y_test, y_pred)
print(confusion_dummy)
# Out:
# [[499   0]
#  [320   0]]

# %%
def conf_matrix(matrix, title):
  ax = sns.heatmap(matrix, annot = True, square = True, fmt = '.0f', cbar = False)
  ax.figure.set_size_inches(12, 6)
  ax.set_title(title, fontsize = 15)

# %%
conf_matrix(confusion_dummy, 'Confusion Matrix - Dummy Classifier')

# %% [markdown]
# ## 5.2: Random Forest Classifier - 65,93%

# %%
randomforest = RandomForestClassifier()

# %%
randomforest.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = randomforest.predict(x_test)

# %%
accuracy_rf = accuracy_score(y_test, y_pred)
print(f'Accuracy score: {round(accuracy_rf*100, 2)}')
# Out:
# Accuracy score: 65.93

# %%
confusion_rf = confusion_matrix(y_test, y_pred)
print(confusion_rf)
# Out:
# [[418  81]
#  [198 122]]

# %%
conf_matrix(confusion_rf, 'Confusion Matrix - Random Forest Classifier')

# %% [markdown]
# ## 5.3: Naive Bayes - 63,25%

# %%
from sklearn.naive_bayes import GaussianNB

# %%
naivebayes = GaussianNB()

# %%
naivebayes.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = naivebayes.predict(x_test)

# %%
accuracy_nb = accuracy_score(y_test, y_pred)
print(f'Accuracy score: {round(accuracy_nb*100, 2)}')
# Out:
# Accuracy score: 63.25

# %%
confusion_nb = confusion_matrix(y_test, y_pred)
print(confusion_nb)
# Out:
# [[441  58]
#  [243  77]]

# %%
conf_matrix(confusion_nb, 'Confusion Matrix - Naive Bayes')

# %% [markdown]
# ## 5.4: kNN - 63,37%

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train_sc = scaler.fit_transform(x_train)

# %%
x_test_sc = scaler.fit_transform(x_test)

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(x_train_sc, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test_sc)

# %%
accuracy_knn = accuracy_score(y_test, y_pred)
print(f'Accuracy score: {round(accuracy_knn*100, 2)}')
# Out:
# Accuracy score: 63.37

# %%
confusion_knn = confusion_matrix(y_test, y_pred)
print(confusion_knn)
# Out:
# [[392 107]
#  [193 127]]

# %%
conf_matrix(confusion_knn, 'Confusion Matrix - KNeighborsClassifier')

# %% [markdown]
# ## 5.5: Random Forest with Cross-Validate - 66,54%

# %%
from sklearn.model_selection import cross_validate

# %%
model = RandomForestClassifier()

# %%
result = cross_validate(model, x, y, cv = 10)

# %%
media = result['test_score'].mean()
dsvpad = result['test_score'].std()

# %%
print(f'Mean: {media} │ Standard Deviation: {dsvpad}')
# Out:
# Mean: 0.6450044752741106 │ Standard Deviation: 0.033043537323143427

# %%
from sklearn.model_selection import StratifiedKFold

# %%
skfold = StratifiedKFold(n_splits=10, shuffle = True)

# %%
result = cross_validate(model, x, y, cv = skfold)

# %%
def resultado(result):
  media = result['test_score'].mean()
  dsvpad = result['test_score'].std()
  intervalo = (media - 2*dsvpad, media + 2*dsvpad)
  print(f'Results mean: {round(media*100, 2)}%')
  print(f'Confidence interval: {round(intervalo[0]*100,2)}% to {round(intervalo[1]*100,2)}%')

# %% [markdown]
# Results with cross-validate:

# %%
resultado(result)
# Out:
# Results mean: 66.54%
# Confidence interval: 63.68% to 69.41%
